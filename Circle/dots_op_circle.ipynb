# %%
# 匯入keras
from tensorflow import keras
 
# 以下為做DNN常引入的重要模組
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
import pandas as pd # 資料處理套件
import matplotlib.pyplot as plt # 繪圖套件

# %% [markdown]
# ## 讀入資料、處理

# %%
# 讀入資料集
dots = pd.read_csv("dots.csv")
dots.columns = [ 'x', 'y', 'c' ] # 加上每欄的名稱

# %%
# 查看資料前5筆資料
print("前5筆資料\n")
dots.head()
# Out:
# 前5筆資料
#      x    y  c
# 0  405  952  0
# 1  288  138  1
# 2  566  141  1
# 3  534  154  1
# 4  987  686  0

# %%
# 分割訓練、測試資料：4/5 拿來訓練、1/5 拿來測試訓練結果
train_i, test_i, train_o, test_o = train_test_split (
    dots.drop(['c'], axis = 1),     # 特徵
    dots['c'],   # 結果
    test_size = 0.4  #測試資料占 1/5
)

# %%
print (train_i)
print (train_o)
# Out:
#        x    y
# 149  269  316
# 982  975  686
# 995  967  794
# 635  601  383
# 819  357  731
# ..   ...  ...
# 546   86   84
# 934  377  988
# 494  699  567
# 539  959  548
# 316  733  652
#
# [599 rows x 2 columns]
# 149    1
# 982    0
# 995    0
# 635    0
# 819    0
#       ..
# 546    1
# 934    0
# 494    0
# 539    0
# 316    0
# Name: c, Length: 599, dtype: int64

# %% [markdown]
# ## 類神經網路模型建構與執行

# %%
#模型初始化
model = Sequential()
#類神經網路建構
model.add(Dense(10, input_dim=2))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(1))

# %%
#類神經網路編譯
model.compile(loss="mse",optimizer='adam')

# %%
#類神經網路視覺化
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#模型訓練
history = model.fit(train_i,train_o,    #輸入與輸出
          epochs = 100,      #迭代數
          verbose = 1,      #顯示訓練過程
          validation_split = 0.4, #驗證資料分割比例
)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 48ms/step - loss: 262.2343 - val_loss: 0.5028
# Epoch 2/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.5041 - val_loss: 0.2972
# Epoch 3/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.3031 - val_loss: 0.2909
# Epoch 4/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2376 - val_loss: 0.4811
# Epoch 5/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.3319 - val_loss: 0.4540
# Epoch 6/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.3084 - val_loss: 0.2692
# Epoch 7/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2448 - val_loss: 0.2826
# Epoch 8/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2010 - val_loss: 0.2881
# Epoch 9/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2067 - val_loss: 0.2437
# Epoch 10/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1969 - val_loss: 0.2472
# Epoch 11/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1999 - val_loss: 0.2661
# Epoch 12/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1899 - val_loss: 0.2515
# Epoch 13/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1847 - val_loss: 0.2299
# Epoch 14/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1833 - val_loss: 0.2362
# Epoch 15/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1637 - val_loss: 0.2231
# Epoch 16/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1904 - val_loss: 0.2035
# Epoch 17/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1585 - val_loss: 0.2040
# Epoch 18/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1599 - val_loss: 0.1896
# Epoch 19/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1424 - val_loss: 0.1970
# Epoch 20/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1429 - val_loss: 0.1779
# Epoch 21/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1381 - val_loss: 0.1799
# Epoch 22/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1337 - val_loss: 0.2208
# Epoch 23/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1291 - val_loss: 0.1469
# Epoch 24/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1121 - val_loss: 0.1446
# Epoch 25/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1105 - val_loss: 0.1340
# Epoch 26/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0996 - val_loss: 0.1110
# Epoch 27/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0940 - val_loss: 0.1186
# Epoch 28/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1243 - val_loss: 0.1165
# Epoch 29/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0924 - val_loss: 0.1584
# Epoch 30/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0832 - val_loss: 0.1041
# Epoch 31/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0662 - val_loss: 0.0872
# Epoch 32/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0646 - val_loss: 0.0968
# Epoch 33/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0843 - val_loss: 0.1000
# Epoch 34/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0742 - val_loss: 0.0893
# Epoch 35/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0606 - val_loss: 0.0850
# Epoch 36/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0554 - val_loss: 0.0742
# Epoch 37/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0744 - val_loss: 0.0729
# Epoch 38/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0607 - val_loss: 0.1037
# Epoch 39/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0634 - val_loss: 0.0686
# Epoch 40/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0610 - val_loss: 0.0959
# Epoch 41/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0803 - val_loss: 0.0967
# Epoch 42/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0645 - val_loss: 0.0880
# Epoch 43/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0547 - val_loss: 0.0613
# Epoch 44/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0516 - val_loss: 0.0889
# Epoch 45/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0719 - val_loss: 0.0680
# Epoch 46/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0569 - val_loss: 0.0695
# Epoch 47/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0591 - val_loss: 0.1017
# Epoch 48/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0678 - val_loss: 0.0704
# Epoch 49/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0535 - val_loss: 0.0651
# Epoch 50/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0509 - val_loss: 0.0530
# Epoch 51/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0527 - val_loss: 0.0530
# Epoch 52/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0534 - val_loss: 0.0523
# Epoch 53/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0558 - val_loss: 0.0650
# Epoch 54/100
# 12/12 [==============================] - 0s 36ms/step - loss: 0.0566 - val_loss: 0.0541
# Epoch 55/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0535 - val_loss: 0.0476
# Epoch 56/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0418 - val_loss: 0.0476
# Epoch 57/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0441 - val_loss: 0.0510
# Epoch 58/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0523 - val_loss: 0.0544
# Epoch 59/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0410 - val_loss: 0.0493
# Epoch 60/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0442 - val_loss: 0.0475
# Epoch 61/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0393 - val_loss: 0.0419
# Epoch 62/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0352 - val_loss: 0.0360
# Epoch 63/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0366 - val_loss: 0.0922
# Epoch 64/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0689 - val_loss: 0.0566
# Epoch 65/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0472 - val_loss: 0.0724
# Epoch 66/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0389 - val_loss: 0.0419
# Epoch 67/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0395 - val_loss: 0.0367
# Epoch 68/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0316 - val_loss: 0.0393
# Epoch 69/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0350 - val_loss: 0.0347
# Epoch 70/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0298 - val_loss: 0.0417
# Epoch 71/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0326 - val_loss: 0.0340
# Epoch 72/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0360 - val_loss: 0.0569
# Epoch 73/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0379 - val_loss: 0.0449
# Epoch 74/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0290 - val_loss: 0.0633
# Epoch 75/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0447 - val_loss: 0.0617
# Epoch 76/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0339 - val_loss: 0.1124
# Epoch 77/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0545 - val_loss: 0.1117
# Epoch 78/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0528 - val_loss: 0.0419
# Epoch 79/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0369 - val_loss: 0.0480
# Epoch 80/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0359 - val_loss: 0.0482
# Epoch 81/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0319 - val_loss: 0.0354
# Epoch 82/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0292 - val_loss: 0.0421
# Epoch 83/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0471 - val_loss: 0.0392
# Epoch 84/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0331 - val_loss: 0.0426
# Epoch 85/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0275 - val_loss: 0.0317
# Epoch 86/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0312 - val_loss: 0.0514
# Epoch 87/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0305 - val_loss: 0.0491
# Epoch 88/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0277 - val_loss: 0.0331
# Epoch 89/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0262 - val_loss: 0.0390
# Epoch 90/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0306 - val_loss: 0.0332
# Epoch 91/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0324 - val_loss: 0.0426
# Epoch 92/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0249 - val_loss: 0.0263
# Epoch 93/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0510 - val_loss: 0.0357
# Epoch 94/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0351 - val_loss: 0.0534
# Epoch 95/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0415 - val_loss: 0.0271
# Epoch 96/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0393 - val_loss: 0.0504
# Epoch 97/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0274 - val_loss: 0.0494
# Epoch 98/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0265 - val_loss: 0.0256
# Epoch 99/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0219 - val_loss: 0.0820
# Epoch 100/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0555 - val_loss: 0.0984

# %% [markdown]
# ## 結果與評估

# %%
# 使用訓練結果 (inference, 推論)：拿先前分割為測試集的資料 test_i 來測試
inference_o = model.predict(test_i)

# %%
# 畫出 test_i 子資料集的推論結果
inf_o_list = inference_o.tolist()
# plt.gca().invert_yaxis()
for i in range (len (inf_o_list)):
  plt.plot (test_i.iloc [i]['x'], test_i.iloc [i]['y'], 'bo' if inf_o_list [i][0] < .4 else 'ro')

# %%
# 比較原來的資料
# plt.gca().invert_yaxis()
for index, row in dots.iterrows():
  plt.plot (row['x'], row['y'], 'bo' if row ['c'] == 0 else 'ro')

# %%
#結果評估
train_result = model.evaluate(train_i,train_o) # 先以 train_i 為輸入用訓練好的 model 做推論，然後和 train_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 train_result
test_result = model.evaluate(test_i,test_o) # 先以 test_i 為輸入用訓練好的 model 做推論，然後和 test_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 test_result
print("-----------")
print("train loss:", train_result)
print("test loss:", test_result)
# Out:
# 19/19 [==============================] - 0s 8ms/step - loss: 0.0798
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1014
# -----------
# train loss: 0.07978875935077667
# test loss: 0.10143780708312988

# %%
# 訓練過程 (損失) 誤差變化
 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.title("loss history")
plt.legend(['train_loss', 'validation_loss'], loc = 'upper left')
plt.xlabel("epoch")
 
plt.tight_layout()
plt.show()

# %%
# 計算原來希望訓練後的模型推論成 1 的測資實際推論為甚麼值的平均值
rdi = dots.loc [dots ['c'] == 1]
rdo = model.predict (rdi.drop (['c'], axis = 1))
sum (rdo) / len (rdo)
# Out:
# array([0.6814846], dtype=float32)

# %%
# 計算原來希望訓練後的模型推論成 0 的測資實際推論為甚麼值的平均值
bli = dots.loc [dots ['c'] == 0]
blo = model.predict (bli.drop (['c'], axis = 1))
sum (blo) / len (blo)
# Out:
# array([-0.01170152], dtype=float32)
