# %% [markdown]
# ## 匯入套件

# %%
# 匯入keras
from tensorflow import keras
 
# 以下為做DNN常引入的重要模組
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
import pandas as pd # 資料處理套件
import matplotlib.pyplot as plt # 繪圖套件

# %% [markdown]
# ## 讀入資料、處理

# %%
# 讀入資料集 - "grades.csv" (在首頁連結第 2 階段課程其他資料：https://drive.google.com/drive/u/1/folders/1KFEBnGxpEWBSai8HnXkNrzvziKgsQbe8)
# 原始資料檔已經有欄位標籤，不須要另外加上
data0 = pd.read_csv('grades.csv')
print("欄:", len(data0.columns))
print("列:", len(data0))
# Out:
# 欄: 33
# 列: 395

# %%
# 非數字資料編碼成數字 (one-hot encoding: https://medium.com/@PatHuang/初學python手記-3-資料前處理-label-encoding-one-hot-encoding-85c983d63f87)
data = pd.get_dummies (data0)
print("原來有哪些欄位")
print(data0.columns)
print("One-hot encoding 後的欄位")
print(data.columns)
print("例如原來 shcool 欄位本有哪些值")
print(data0.school)
# Out:
# 原來有哪些欄位
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'Tech', 'Math', 'Eng'],
#       dtype='object')
# One-hot encoding 後的欄位
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'Tech',
#        'Math', 'Eng', 'school_大同', 'school_松山', 'sex_F', 'sex_M', 'address_R',
#        'address_U', 'famsize_GT3', 'famsize_LE3', 'Pstatus_A', 'Pstatus_T',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other', 'schoolsup_no', 'schoolsup_yes',
#        'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes', 'activities_no',
#        'activities_yes', 'nursery_no', 'nursery_yes', 'higher_no',
#        'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
#        'romantic_yes'],
#       dtype='object')
# 例如原來 shcool 欄位本有哪些值
# 0      松山
# 1      松山
# 2      松山
# 3      松山
# 4      松山
#        ..
# 390    大同
# 391    大同
# 392    大同
# 393    大同
# 394    大同
# Name: school, Length: 395, dtype: object

# %% [markdown]
# ```
# data_df.drop(['Tech','Math','Eng'], axis=1)
# ```
# 會回傳捨去 'Tech','Math','Eng' 三個欄位的資料
# ```
# data[['Tech','Math','Eng']]
# ```
# 會取得 'Tech','Math','Eng' 三個欄位的資料

# %%
# 分割測試、訓練資料
train_i, test_i, train_o, test_o = train_test_split (
    data.drop(['Tech','Math','Eng'], axis=1),     # 特徵
    data[['Tech','Math','Eng']],   # 結果
    test_size = 0.4  #測試資料占 1/5
)

# %% [markdown]
# ## 類神經網路模型建構與訓練

# %%
#模型初始化
model = Sequential()
#類神經網路建構
model.add(Dense(20, input_dim=len(train_i.columns)))
model.add(Dense(20,activation="relu"))
model.add(Dense(19,activation="relu"))
model.add(Dense(18,activation="relu"))
model.add(Dense(17,activation="relu"))
model.add(Dense(16,activation="relu"))
model.add(Dense(15,activation="relu"))
model.add(Dense(14,activation="relu"))

model.add(Dense(3))

# %%
#類神經網路編譯
model.compile(loss="mse",optimizer='adam')

# %%
#類神經網路視覺化
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#模型訓練
history = model.fit(train_i,train_o,    #輸入與輸出
  epochs = 40,      #迭代數
  verbose = 1,      #顯示訓練過程
  validation_split = 0.4, #驗證資料分割比例
)
# Out:
# Epoch 1/40
# 5/5 [==============================] - 1s 71ms/step - loss: 133.4292 - val_loss: 130.7614
# Epoch 2/40
# 5/5 [==============================] - 0s 12ms/step - loss: 131.2849 - val_loss: 128.4070
# Epoch 3/40
# 5/5 [==============================] - 0s 7ms/step - loss: 128.5589 - val_loss: 125.1875
# Epoch 4/40
# 5/5 [==============================] - 0s 7ms/step - loss: 124.7926 - val_loss: 120.2958
# Epoch 5/40
# 5/5 [==============================] - 0s 17ms/step - loss: 119.0592 - val_loss: 112.8491
# Epoch 6/40
# 5/5 [==============================] - 0s 7ms/step - loss: 110.3295 - val_loss: 101.6698
# Epoch 7/40
# 5/5 [==============================] - 0s 8ms/step - loss: 97.5593 - val_loss: 85.9903
# Epoch 8/40
# 5/5 [==============================] - 0s 7ms/step - loss: 80.2068 - val_loss: 66.6086
# Epoch 9/40
# 5/5 [==============================] - 0s 8ms/step - loss: 61.5905 - val_loss: 49.0496
# Epoch 10/40
# 5/5 [==============================] - 0s 7ms/step - loss: 47.2871 - val_loss: 39.2904
# Epoch 11/40
# 5/5 [==============================] - 0s 7ms/step - loss: 38.2246 - val_loss: 30.6400
# Epoch 12/40
# 5/5 [==============================] - 0s 9ms/step - loss: 29.9503 - val_loss: 23.4177
# Epoch 13/40
# 5/5 [==============================] - 0s 7ms/step - loss: 24.8235 - val_loss: 20.0401
# Epoch 14/40
# 5/5 [==============================] - 0s 8ms/step - loss: 21.9307 - val_loss: 17.6606
# Epoch 15/40
# 5/5 [==============================] - 0s 8ms/step - loss: 20.0243 - val_loss: 16.1345
# Epoch 16/40
# 5/5 [==============================] - 0s 8ms/step - loss: 19.0394 - val_loss: 15.2767
# Epoch 17/40
# 5/5 [==============================] - 0s 7ms/step - loss: 18.3658 - val_loss: 14.9904
# Epoch 18/40
# 5/5 [==============================] - 0s 8ms/step - loss: 18.1323 - val_loss: 14.8270
# Epoch 19/40
# 5/5 [==============================] - 0s 10ms/step - loss: 18.0723 - val_loss: 14.7342
# Epoch 20/40
# 5/5 [==============================] - 0s 8ms/step - loss: 18.1351 - val_loss: 14.6596
# Epoch 21/40
# 5/5 [==============================] - 0s 7ms/step - loss: 17.8410 - val_loss: 14.5512
# Epoch 22/40
# 5/5 [==============================] - 0s 10ms/step - loss: 17.7501 - val_loss: 14.6859
# Epoch 23/40
# 5/5 [==============================] - 0s 9ms/step - loss: 17.6556 - val_loss: 14.4729
# Epoch 24/40
# 5/5 [==============================] - 0s 12ms/step - loss: 17.4685 - val_loss: 14.3524
# Epoch 25/40
# 5/5 [==============================] - 0s 7ms/step - loss: 17.3177 - val_loss: 14.3563
# Epoch 26/40
# 5/5 [==============================] - 0s 8ms/step - loss: 17.2689 - val_loss: 14.2705
# Epoch 27/40
# 5/5 [==============================] - 0s 8ms/step - loss: 17.0824 - val_loss: 14.1852
# Epoch 28/40
# 5/5 [==============================] - 0s 8ms/step - loss: 17.1806 - val_loss: 14.1877
# Epoch 29/40
# 5/5 [==============================] - 0s 8ms/step - loss: 16.9274 - val_loss: 14.0376
# Epoch 30/40
# 5/5 [==============================] - 0s 7ms/step - loss: 16.7930 - val_loss: 14.0308
# Epoch 31/40
# 5/5 [==============================] - 0s 8ms/step - loss: 16.6570 - val_loss: 13.8537
# Epoch 32/40
# 5/5 [==============================] - 0s 8ms/step - loss: 16.5704 - val_loss: 13.7913
# Epoch 33/40
# 5/5 [==============================] - 0s 10ms/step - loss: 16.4387 - val_loss: 13.6974
# Epoch 34/40
# 5/5 [==============================] - 0s 7ms/step - loss: 16.3506 - val_loss: 13.6342
# Epoch 35/40
# 5/5 [==============================] - 0s 8ms/step - loss: 16.2539 - val_loss: 13.5989
# Epoch 36/40
# 5/5 [==============================] - 0s 9ms/step - loss: 16.1901 - val_loss: 13.4746
# Epoch 37/40
# 5/5 [==============================] - 0s 8ms/step - loss: 16.0024 - val_loss: 13.3974
# Epoch 38/40
# 5/5 [==============================] - 0s 8ms/step - loss: 15.9366 - val_loss: 13.3199
# Epoch 39/40
# 5/5 [==============================] - 0s 8ms/step - loss: 15.7764 - val_loss: 13.2263
# Epoch 40/40
# 5/5 [==============================] - 0s 8ms/step - loss: 15.6790 - val_loss: 13.1539

# %% [markdown]
# ## 結果與評估

# %% [markdown]
# <code>model.evaluate (*input*, *ex_output*)</code><br><br>
# 先以 *input* 為輸入用訓練好的 model 做推論，然後和 *ex_output* (期望正確的輸出) 做比較，算出誤差後回傳

# %%
# 訓練結果評估
train_result = model.evaluate(train_i, train_o)
test_result = model.evaluate(test_i, test_o)
print("-----------")
print("train loss:", train_result)
print("test loss:", test_result)
# Out:
# 8/8 [==============================] - 0s 2ms/step - loss: 14.6067
# 5/5 [==============================] - 0s 3ms/step - loss: 13.1063
# -----------
# train loss: 14.606701850891113
# test loss: 13.106337547302246

# %%
# 訓練過程 (損失) 誤差變化
 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.title("loss history")
plt.legend(['train_loss', 'validation_loss'], loc = 'upper left')
plt.xlabel("epoch")
 
plt.tight_layout()
plt.show()

# %% [markdown]
# ***繪製某科成績的推論結果分佈***

# %%
# 設定圖的尺寸
plt.figure(figsize=(16, 4)) # 寬, 高

# 取得測試資料的推論結果
inference_o = model.predict(test_i) # inference_o 會是一個 numpy (二維) 陣列 (np_array)
# 繪製推論結果
plt.scatter(list(range(len(inference_o))), inference_o[:, 1], c="blue", alpha=0.8)
# 繪製原來正確結果
plt.scatter(list(range(len(test_o))), test_o['Math'], c="orange", alpha=0.8)

# 誤差
# plt.scatter(list(range(len(test_o))), abs(inference_o[:, 1] - test_o['Math']), c="red", alpha=0.3)

plt.show ()

# %% [markdown]
# 如果 inference_o 是一個 np_array<br>
# <code>inference \[:,0\]</code> 是 0 那一欄所有 (:) 列的內容

# %%
# 推論結果偏離分佈直方圖
import seaborn as sns

for i, j in zip ([0,1,2], ['Tech','Math','Eng']):
  error = inference_o[:,i] - test_o[j].to_numpy() # ... 換成測試集原來正確結果的變數名稱
  # 推論結果偏離直方圖
  sns.histplot(error, kde=True, bins=20)
  plt.xlim(-20,20)
  plt.title(j)
  plt.show()
