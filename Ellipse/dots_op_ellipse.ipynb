# %%
# 匯入keras
from tensorflow import keras
 
# 以下為做DNN常引入的重要模組
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
import pandas as pd # 資料處理套件
import matplotlib.pyplot as plt # 繪圖套件

# %% [markdown]
# ## 讀入資料、處理

# %%
# 讀入資料集
dots = pd.read_csv("dots.csv")
dots.columns = [ 'x', 'y', 'c' ] # 加上每欄的名稱

# %%
# 查看資料前5筆資料
print("前5筆資料\n")
dots.head()
# Out:
# 前5筆資料
#      x    y  c
# 0  190  535  0
# 1  809  830  0
# 2  625  748  0
# 3  770   92  0
# 4  370  491  1

# %%
# 分割訓練、測試資料：4/5 拿來訓練、1/5 拿來測試訓練結果
train_i, test_i, train_o, test_o = train_test_split (
    dots.drop(['c'], axis = 1),     # 特徵
    dots['c'],   # 結果
    test_size = 0.3  #測試資料占 1/5
)

# %%
print (train_i)
print (train_o)
# Out:
#        x    y
# 415  853  472
# 631  613  937
# 647   18  588
# 424  689   94
# 327  555  791
# ..   ...  ...
# 24   178  977
# 832  759  888
# 985  735  502
# 487  902   36
# 441  564   14
#
# [699 rows x 2 columns]
# 415    0
# 631    0
# 647    0
# 424    0
# 327    0
#       ..
# 24     0
# 832    0
# 985    1
# 487    0
# 441    0
# Name: c, Length: 699, dtype: int64

# %% [markdown]
# ## 類神經網路模型建構與執行

# %%
#模型初始化
model = Sequential()
#類神經網路建構
model.add(Dense(10, input_dim=2))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(1))

# %%
#類神經網路編譯
model.compile(loss="mse",optimizer='adam')

# %%
#類神經網路視覺化
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#模型訓練
history = model.fit(train_i,train_o,    #輸入與輸出
          epochs = 100,      #迭代數
          verbose = 1,      #顯示訓練過程
          validation_split = 0.3, #驗證資料分割比例
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 42ms/step - loss: 222.0732 - val_loss: 0.3569
# Epoch 2/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.4819 - val_loss: 0.2789
# Epoch 3/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.2494 - val_loss: 0.1748
# Epoch 4/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1994 - val_loss: 0.1801
# Epoch 5/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1858 - val_loss: 0.1535
# Epoch 6/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2109 - val_loss: 0.1649
# Epoch 7/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2116 - val_loss: 0.1904
# Epoch 8/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1866 - val_loss: 0.1636
# Epoch 9/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1924 - val_loss: 0.1810
# Epoch 10/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1784 - val_loss: 0.2489
# Epoch 11/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1962 - val_loss: 0.1833
# Epoch 12/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1994 - val_loss: 0.1532
# Epoch 13/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1821 - val_loss: 0.1478
# Epoch 14/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1730 - val_loss: 0.1523
# Epoch 15/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1687 - val_loss: 0.2169
# Epoch 16/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1874 - val_loss: 0.1537
# Epoch 17/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1900 - val_loss: 0.1453
# Epoch 18/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1770 - val_loss: 0.1562
# Epoch 19/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1710 - val_loss: 0.1608
# Epoch 20/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1731 - val_loss: 0.1594
# Epoch 21/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1721 - val_loss: 0.1545
# Epoch 22/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1676 - val_loss: 0.1336
# Epoch 23/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1648 - val_loss: 0.1330
# Epoch 24/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1602 - val_loss: 0.1355
# Epoch 25/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1633 - val_loss: 0.1508
# Epoch 26/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1602 - val_loss: 0.1525
# Epoch 27/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1591 - val_loss: 0.1520
# Epoch 28/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1661 - val_loss: 0.1385
# Epoch 29/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1627 - val_loss: 0.1478
# Epoch 30/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1571 - val_loss: 0.1422
# Epoch 31/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1554 - val_loss: 0.1352
# Epoch 32/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1551 - val_loss: 0.1260
# Epoch 33/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1544 - val_loss: 0.1426
# Epoch 34/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1499 - val_loss: 0.1341
# Epoch 35/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1439 - val_loss: 0.1259
# Epoch 36/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1480 - val_loss: 0.1267
# Epoch 37/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1466 - val_loss: 0.1279
# Epoch 38/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1418 - val_loss: 0.1253
# Epoch 39/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1399 - val_loss: 0.1179
# Epoch 40/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1371 - val_loss: 0.1180
# Epoch 41/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1364 - val_loss: 0.1109
# Epoch 42/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1317 - val_loss: 0.1068
# Epoch 43/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1289 - val_loss: 0.1045
# Epoch 44/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1234 - val_loss: 0.1142
# Epoch 45/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1302 - val_loss: 0.1141
# Epoch 46/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.1261 - val_loss: 0.1249
# Epoch 47/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1254 - val_loss: 0.1044
# Epoch 48/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1295 - val_loss: 0.0945
# Epoch 49/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1188 - val_loss: 0.1172
# Epoch 50/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1214 - val_loss: 0.0974
# Epoch 51/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1116 - val_loss: 0.0995
# Epoch 52/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1187 - val_loss: 0.0901
# Epoch 53/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0996 - val_loss: 0.0863
# Epoch 54/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0918 - val_loss: 0.1012
# Epoch 55/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0949 - val_loss: 0.0750
# Epoch 56/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0919 - val_loss: 0.0771
# Epoch 57/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0922 - val_loss: 0.0650
# Epoch 58/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0748 - val_loss: 0.0575
# Epoch 59/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0990 - val_loss: 0.0996
# Epoch 60/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0689 - val_loss: 0.0571
# Epoch 61/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0575 - val_loss: 0.0617
# Epoch 62/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0520 - val_loss: 0.0579
# Epoch 63/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0551 - val_loss: 0.0502
# Epoch 64/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0527 - val_loss: 0.0799
# Epoch 65/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0552 - val_loss: 0.0500
# Epoch 66/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0543 - val_loss: 0.0593
# Epoch 67/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0622 - val_loss: 0.0639
# Epoch 68/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0521 - val_loss: 0.1043
# Epoch 69/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0732 - val_loss: 0.0743
# Epoch 70/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0563 - val_loss: 0.0455
# Epoch 71/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0477 - val_loss: 0.0583
# Epoch 72/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0504 - val_loss: 0.0624
# Epoch 73/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0583 - val_loss: 0.1023
# Epoch 74/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0608 - val_loss: 0.0495
# Epoch 75/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0541 - val_loss: 0.1513
# Epoch 76/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0793 - val_loss: 0.0590
# Epoch 77/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0672 - val_loss: 0.0542
# Epoch 78/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0594 - val_loss: 0.0481
# Epoch 79/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0455 - val_loss: 0.0511
# Epoch 80/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0509 - val_loss: 0.0645
# Epoch 81/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0536 - val_loss: 0.0692
# Epoch 82/100
# 16/16 [==============================] - 0s 32ms/step - loss: 0.0499 - val_loss: 0.0603
# Epoch 83/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0495 - val_loss: 0.0401
# Epoch 84/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0508 - val_loss: 0.0608
# Epoch 85/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0457 - val_loss: 0.0629
# Epoch 86/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0455 - val_loss: 0.0402
# Epoch 87/100
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0495 - val_loss: 0.0737
# Epoch 88/100
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0435 - val_loss: 0.0488
# Epoch 89/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0476 - val_loss: 0.0459
# Epoch 90/100
# 16/16 [==============================] - 0s 32ms/step - loss: 0.0532 - val_loss: 0.0424
# Epoch 91/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0414 - val_loss: 0.0568
# Epoch 92/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0535 - val_loss: 0.0644
# Epoch 93/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0547 - val_loss: 0.0478
# Epoch 94/100
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0381 - val_loss: 0.0484
# Epoch 95/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0553 - val_loss: 0.0489
# Epoch 96/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0470 - val_loss: 0.0511
# Epoch 97/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.0584 - val_loss: 0.0475
# Epoch 98/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0612 - val_loss: 0.0591
# Epoch 99/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0555 - val_loss: 0.0531
# Epoch 100/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0407 - val_loss: 0.0526

# %% [markdown]
# ## 結果與評估

# %%
# 使用訓練結果 (inference, 推論)：拿先前分割為測試集的資料 test_i 來測試
inference_o = model.predict(test_i)

# %%
# 畫出 test_i 子資料集的推論結果
inf_o_list = inference_o.tolist()
# plt.gca().invert_yaxis()
for i in range (len (inf_o_list)):
  plt.plot (test_i.iloc [i]['x'], test_i.iloc [i]['y'], 'bo' if inf_o_list [i][0] < .4 else 'ro')

# %%
# 比較原來的資料
# plt.gca().invert_yaxis()
for index, row in dots.iterrows():
  plt.plot (row['x'], row['y'], 'bo' if row ['c'] == 0 else 'ro')

# %%
#結果評估
train_result = model.evaluate(train_i,train_o) # 先以 train_i 為輸入用訓練好的 model 做推論，然後和 train_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 train_result
test_result = model.evaluate(test_i,test_o) # 先以 test_i 為輸入用訓練好的 model 做推論，然後和 test_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 test_result
print("-----------")
print("train loss:", train_result)
print("test loss:", test_result)
# Out:
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0517
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0493
# -----------
# train loss: 0.05172215402126312
# test loss: 0.04931076988577843

# %%
# 訓練過程 (損失) 誤差變化
 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.title("loss history")
plt.legend(['train_loss', 'validation_loss'], loc = 'upper left')
plt.xlabel("epoch")
 
plt.tight_layout()
plt.show()

# %%
# 計算原來希望訓練後的模型推論成 1 的測資實際推論為甚麼值的平均值
rdi = dots.loc [dots ['c'] == 1]
rdo = model.predict (rdi.drop (['c'], axis = 1))
sum (rdo) / len (rdo)
# Out:
# array([0.7321574], dtype=float32)

# %%
# 計算原來希望訓練後的模型推論成 0 的測資實際推論為甚麼值的平均值
bli = dots.loc [dots ['c'] == 0]
blo = model.predict (bli.drop (['c'], axis = 1))
sum (blo) / len (blo)
# Out:
# array([0.01446478], dtype=float32)
