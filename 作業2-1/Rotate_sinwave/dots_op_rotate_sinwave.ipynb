# %%
# 匯入keras
from tensorflow import keras
 
# 以下為做DNN常引入的重要模組
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
import pandas as pd # 資料處理套件
import matplotlib.pyplot as plt # 繪圖套件

# %% [markdown]
# ## 讀入資料、處理

# %%
# 讀入資料集
dots = pd.read_csv("dots.csv")
dots.columns = [ 'x', 'y', 'c' ] # 加上每欄的名稱

# %%
# 查看資料前5筆資料
print("前5筆資料\n")
dots.head()
# Out:
# 前5筆資料
#             x           y  c
# 0  699.864412  892.479575  0
# 1   25.495141  648.213152  1
# 2  347.449052  179.447028  1
# 3  469.283347  467.929964  1
# 4   47.533838  685.352023  1

# %%
# 分割訓練、測試資料：4/5 拿來訓練、1/5 拿來測試訓練結果
train_i, test_i, train_o, test_o = train_test_split (
    dots.drop(['c'], axis = 1),     # 特徵
    dots['c'],   # 結果
    test_size = 0.4  #測試資料占 1/5
)

# %%
print (train_i)
print (train_o)
# Out:
#               x           y
# 260  169.122684  410.366292
# 808  688.331713  255.631087
# 550  192.085591  821.362283
# 768  556.941621  886.309011
# 439  587.356703  780.158538
# ..          ...         ...
# 752  102.095671  358.942761
# 84   782.828384  210.460529
# 497  660.300264  297.010283
# 437  357.747696  937.090702
# 542  844.164217  478.622636
#
# [600 rows x 2 columns]
# 260    1
# 808    1
# 550    1
# 768    0
# 439    0
#       ..
# 752    1
# 84     0
# 497    1
# 437    0
# 542    0
# Name: c, Length: 600, dtype: int64

# %% [markdown]
# ## 類神經網路模型建構與執行

# %%
#模型初始化
model = Sequential()
#類神經網路建構
model.add(Dense(10, input_dim=2))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(1))

# %%
#類神經網路編譯
model.compile(loss="mse",optimizer='adam')

# %%
#類神經網路視覺化
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#模型訓練
history = model.fit(train_i,train_o,    #輸入與輸出
          epochs = 100,      #迭代數
          verbose = 1,      #顯示訓練過程
          validation_split = 0.4, #驗證資料分割比例
)
# Out:
# Epoch 1/100
# 12/12 [==============================] - 1s 48ms/step - loss: 545.4402 - val_loss: 0.3810
# Epoch 2/100
# 12/12 [==============================] - 0s 36ms/step - loss: 1.2343 - val_loss: 0.4460
# Epoch 3/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.5030 - val_loss: 0.6500
# Epoch 4/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.5676 - val_loss: 0.3536
# Epoch 5/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.3257 - val_loss: 0.4698
# Epoch 6/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.3382 - val_loss: 0.3338
# Epoch 7/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.3774 - val_loss: 0.3238
# Epoch 8/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.3317 - val_loss: 0.3348
# Epoch 9/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2882 - val_loss: 0.3987
# Epoch 10/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2894 - val_loss: 0.3180
# Epoch 11/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2772 - val_loss: 0.2943
# Epoch 12/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.3036 - val_loss: 0.2914
# Epoch 13/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.3128 - val_loss: 0.3217
# Epoch 14/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2632 - val_loss: 0.2836
# Epoch 15/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.2533 - val_loss: 0.2697
# Epoch 16/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.2502 - val_loss: 0.2611
# Epoch 17/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2340 - val_loss: 0.2506
# Epoch 18/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.2420 - val_loss: 0.2414
# Epoch 19/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2276 - val_loss: 0.3045
# Epoch 20/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2333 - val_loss: 0.3120
# Epoch 21/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2389 - val_loss: 0.2274
# Epoch 22/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.2472 - val_loss: 0.2811
# Epoch 23/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2178 - val_loss: 0.2457
# Epoch 24/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.2076 - val_loss: 0.2632
# Epoch 25/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.2367 - val_loss: 0.2893
# Epoch 26/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.2032 - val_loss: 0.2131
# Epoch 27/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1951 - val_loss: 0.1956
# Epoch 28/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1880 - val_loss: 0.1891
# Epoch 29/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1978 - val_loss: 0.1961
# Epoch 30/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1865 - val_loss: 0.2131
# Epoch 31/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1919 - val_loss: 0.1674
# Epoch 32/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1740 - val_loss: 0.1627
# Epoch 33/100
# 12/12 [==============================] - 0s 28ms/step - loss: 0.1573 - val_loss: 0.2196
# Epoch 34/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.1898 - val_loss: 0.1631
# Epoch 35/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1568 - val_loss: 0.1485
# Epoch 36/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1574 - val_loss: 0.1703
# Epoch 37/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1477 - val_loss: 0.1328
# Epoch 38/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1334 - val_loss: 0.1384
# Epoch 39/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1437 - val_loss: 0.1266
# Epoch 40/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1284 - val_loss: 0.1293
# Epoch 41/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1259 - val_loss: 0.1104
# Epoch 42/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1239 - val_loss: 0.1166
# Epoch 43/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1075 - val_loss: 0.1023
# Epoch 44/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1174 - val_loss: 0.1588
# Epoch 45/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1255 - val_loss: 0.0968
# Epoch 46/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1077 - val_loss: 0.1109
# Epoch 47/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1098 - val_loss: 0.0954
# Epoch 48/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1062 - val_loss: 0.0993
# Epoch 49/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1072 - val_loss: 0.1165
# Epoch 50/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.1053 - val_loss: 0.0905
# Epoch 51/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1089 - val_loss: 0.0814
# Epoch 52/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0938 - val_loss: 0.0817
# Epoch 53/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0917 - val_loss: 0.0785
# Epoch 54/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0910 - val_loss: 0.0986
# Epoch 55/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1043 - val_loss: 0.0848
# Epoch 56/100
# 12/12 [==============================] - 0s 29ms/step - loss: 0.0957 - val_loss: 0.0802
# Epoch 57/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0945 - val_loss: 0.1078
# Epoch 58/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0907 - val_loss: 0.0776
# Epoch 59/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0903 - val_loss: 0.0779
# Epoch 60/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0831 - val_loss: 0.0847
# Epoch 61/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.1114 - val_loss: 0.0814
# Epoch 62/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.1058 - val_loss: 0.0762
# Epoch 63/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0870 - val_loss: 0.0940
# Epoch 64/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0885 - val_loss: 0.0719
# Epoch 65/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0856 - val_loss: 0.0731
# Epoch 66/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0842 - val_loss: 0.0985
# Epoch 67/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1129 - val_loss: 0.0931
# Epoch 68/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.1030 - val_loss: 0.0746
# Epoch 69/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0862 - val_loss: 0.0779
# Epoch 70/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0849 - val_loss: 0.0706
# Epoch 71/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.1055 - val_loss: 0.0835
# Epoch 72/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0853 - val_loss: 0.0690
# Epoch 73/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0834 - val_loss: 0.0772
# Epoch 74/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0831 - val_loss: 0.0810
# Epoch 75/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0958 - val_loss: 0.0691
# Epoch 76/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0792 - val_loss: 0.0713
# Epoch 77/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0769 - val_loss: 0.0654
# Epoch 78/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0775 - val_loss: 0.0805
# Epoch 79/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0910 - val_loss: 0.0671
# Epoch 80/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0784 - val_loss: 0.0653
# Epoch 81/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0840 - val_loss: 0.0654
# Epoch 82/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0923 - val_loss: 0.0787
# Epoch 83/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0819 - val_loss: 0.0712
# Epoch 84/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0746 - val_loss: 0.0625
# Epoch 85/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0766 - val_loss: 0.0632
# Epoch 86/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0754 - val_loss: 0.0932
# Epoch 87/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0772 - val_loss: 0.0808
# Epoch 88/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0839 - val_loss: 0.0651
# Epoch 89/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0723 - val_loss: 0.0705
# Epoch 90/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0748 - val_loss: 0.0578
# Epoch 91/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0778 - val_loss: 0.0678
# Epoch 92/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0686 - val_loss: 0.0585
# Epoch 93/100
# 12/12 [==============================] - 0s 33ms/step - loss: 0.0696 - val_loss: 0.0592
# Epoch 94/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0697 - val_loss: 0.0638
# Epoch 95/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0705 - val_loss: 0.0607
# Epoch 96/100
# 12/12 [==============================] - 0s 31ms/step - loss: 0.0870 - val_loss: 0.0610
# Epoch 97/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0918 - val_loss: 0.0664
# Epoch 98/100
# 12/12 [==============================] - 0s 30ms/step - loss: 0.0704 - val_loss: 0.0559
# Epoch 99/100
# 12/12 [==============================] - 0s 32ms/step - loss: 0.0742 - val_loss: 0.0648
# Epoch 100/100
# 12/12 [==============================] - 0s 34ms/step - loss: 0.0688 - val_loss: 0.0579

# %% [markdown]
# ## 結果與評估

# %%
# 使用訓練結果 (inference, 推論)：拿先前分割為測試集的資料 test_i 來測試
inference_o = model.predict(test_i)

# %%
# 畫出 test_i 子資料集的推論結果
inf_o_list = inference_o.tolist()
# plt.gca().invert_yaxis()
for i in range (len (inf_o_list)):
  plt.plot (test_i.iloc [i]['x'], test_i.iloc [i]['y'], 'bo' if inf_o_list [i][0] < .4 else 'ro')

# %%
# 比較原來的資料
# plt.gca().invert_yaxis()
for index, row in dots.iterrows():
  plt.plot (row['x'], row['y'], 'bo' if row ['c'] == 0 else 'ro')

# %%
#結果評估
train_result = model.evaluate(train_i,train_o) # 先以 train_i 為輸入用訓練好的 model 做推論，然後和 train_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 train_result
test_result = model.evaluate(test_i,test_o) # 先以 test_i 為輸入用訓練好的 model 做推論，然後和 test_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 test_result
print("-----------")
print("train loss:", train_result)
print("test loss:", test_result)
# Out:
# 19/19 [==============================] - 0s 7ms/step - loss: 0.0663
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0769
# -----------
# train loss: 0.06631651520729065
# test loss: 0.07694414258003235

# %%
# 訓練過程 (損失) 誤差變化
 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.title("loss history")
plt.legend(['train_loss', 'validation_loss'], loc = 'upper left')
plt.xlabel("epoch")
 
plt.tight_layout()
plt.show()

# %%
# 計算原來希望訓練後的模型推論成 1 的測資實際推論為甚麼值的平均值
rdi = dots.loc [dots ['c'] == 1]
rdo = model.predict (rdi.drop (['c'], axis = 1))
sum (rdo) / len (rdo)
# Out:
# array([0.8198662], dtype=float32)

# %%
# 計算原來希望訓練後的模型推論成 0 的測資實際推論為甚麼值的平均值
bli = dots.loc [dots ['c'] == 0]
blo = model.predict (bli.drop (['c'], axis = 1))
sum (blo) / len (blo)
# Out:
# array([0.03342554], dtype=float32)
