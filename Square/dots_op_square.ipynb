# %%
# 匯入keras
from tensorflow import keras
 
# 以下為做DNN常引入的重要模組
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
 
import pandas as pd # 資料處理套件
import matplotlib.pyplot as plt # 繪圖套件

# %% [markdown]
# ## 讀入資料、處理

# %%
# 讀入資料集
dots = pd.read_csv("dots.csv")
dots.columns = [ 'x', 'y', 'c' ] # 加上每欄的名稱

# %%
# 查看資料前5筆資料
print("前5筆資料\n")
dots.head()
# Out:
# 前5筆資料
#      x    y  c
# 0  940  822  1
# 1  330  878  1
# 2  179  120  1
# 3  701  345  0
# 4  967  316  1

# %%
# 分割訓練、測試資料：4/5 拿來訓練、1/5 拿來測試訓練結果
train_i, test_i, train_o, test_o = train_test_split (
    dots.drop(['c'], axis = 1),     # 特徵
    dots['c'],   # 結果
    test_size = 0.3  #測試資料占 1/5
)

# %%
print (train_i)
print (train_o)
# Out:
#        x    y
# 398  272  924
# 873  998  721
# 423  356  547
# 941  691   22
# 797  945  800
# ..   ...  ...
# 232  904  823
# 694   93  763
# 832   96  490
# 530  353  372
# 863  832  284
#
# [699 rows x 2 columns]
# 398    1
# 873    1
# 423    0
# 941    1
# 797    1
#       ..
# 232    1
# 694    1
# 832    1
# 530    0
# 863    1
# Name: c, Length: 699, dtype: int64

# %% [markdown]
# ## 類神經網路模型建構與執行

# %%
#模型初始化
model = Sequential()
#類神經網路建構
model.add(Dense(10, input_dim=2))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(500,activation="relu"))
model.add(Dense(1))

# %%
#類神經網路編譯
model.compile(loss="mse",optimizer='adam')

# %%
#類神經網路視覺化
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True)

# %%
#模型訓練
history = model.fit(train_i,train_o,    #輸入與輸出
          epochs = 100,      #迭代數
          verbose = 1,      #顯示訓練過程
          validation_split = 0.3, #驗證資料分割比例
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 43ms/step - loss: 140.3265 - val_loss: 0.4259
# Epoch 2/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.3466 - val_loss: 0.1776
# Epoch 3/100
# 16/16 [==============================] - 1s 32ms/step - loss: 0.3105 - val_loss: 0.2169
# Epoch 4/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1857 - val_loss: 0.4496
# Epoch 5/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.2606 - val_loss: 0.2176
# Epoch 6/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1872 - val_loss: 0.1776
# Epoch 7/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1891 - val_loss: 0.1982
# Epoch 8/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1837 - val_loss: 0.1767
# Epoch 9/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1911 - val_loss: 0.2062
# Epoch 10/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1758 - val_loss: 0.1821
# Epoch 11/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1703 - val_loss: 0.1737
# Epoch 12/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1712 - val_loss: 0.2041
# Epoch 13/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1788 - val_loss: 0.1778
# Epoch 14/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.1702 - val_loss: 0.2762
# Epoch 15/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1938 - val_loss: 0.1708
# Epoch 16/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1675 - val_loss: 0.1733
# Epoch 17/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1653 - val_loss: 0.2235
# Epoch 18/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1816 - val_loss: 0.1700
# Epoch 19/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1628 - val_loss: 0.1759
# Epoch 20/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1667 - val_loss: 0.1717
# Epoch 21/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1624 - val_loss: 0.2100
# Epoch 22/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1883 - val_loss: 0.1674
# Epoch 23/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1641 - val_loss: 0.1665
# Epoch 24/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1675 - val_loss: 0.1660
# Epoch 25/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1637 - val_loss: 0.1622
# Epoch 26/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1600 - val_loss: 0.1631
# Epoch 27/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1616 - val_loss: 0.1625
# Epoch 28/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1593 - val_loss: 0.1639
# Epoch 29/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1574 - val_loss: 0.1768
# Epoch 30/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1688 - val_loss: 0.1662
# Epoch 31/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1612 - val_loss: 0.1619
# Epoch 32/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1539 - val_loss: 0.1622
# Epoch 33/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1623 - val_loss: 0.1724
# Epoch 34/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1591 - val_loss: 0.1632
# Epoch 35/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1546 - val_loss: 0.1646
# Epoch 36/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1537 - val_loss: 0.1698
# Epoch 37/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1541 - val_loss: 0.1632
# Epoch 38/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1532 - val_loss: 0.1645
# Epoch 39/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1529 - val_loss: 0.1597
# Epoch 40/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1498 - val_loss: 0.1523
# Epoch 41/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1601 - val_loss: 0.1531
# Epoch 42/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1528 - val_loss: 0.1496
# Epoch 43/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1554 - val_loss: 0.1590
# Epoch 44/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1563 - val_loss: 0.1606
# Epoch 45/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1465 - val_loss: 0.1526
# Epoch 46/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1406 - val_loss: 0.1547
# Epoch 47/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1483 - val_loss: 0.1513
# Epoch 48/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1429 - val_loss: 0.1447
# Epoch 49/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1392 - val_loss: 0.1406
# Epoch 50/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1312 - val_loss: 0.1385
# Epoch 51/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1287 - val_loss: 0.1366
# Epoch 52/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1270 - val_loss: 0.1330
# Epoch 53/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1248 - val_loss: 0.1334
# Epoch 54/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1219 - val_loss: 0.1244
# Epoch 55/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1209 - val_loss: 0.1311
# Epoch 56/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1234 - val_loss: 0.1228
# Epoch 57/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1190 - val_loss: 0.1238
# Epoch 58/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1238 - val_loss: 0.1189
# Epoch 59/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1178 - val_loss: 0.1211
# Epoch 60/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1119 - val_loss: 0.1207
# Epoch 61/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1146 - val_loss: 0.1117
# Epoch 62/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1263 - val_loss: 0.1197
# Epoch 63/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1144 - val_loss: 0.1703
# Epoch 64/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.1219 - val_loss: 0.1371
# Epoch 65/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.1232 - val_loss: 0.1133
# Epoch 66/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1157 - val_loss: 0.1206
# Epoch 67/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.1180 - val_loss: 0.1077
# Epoch 68/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1057 - val_loss: 0.1185
# Epoch 69/100
# 16/16 [==============================] - 0s 31ms/step - loss: 0.1030 - val_loss: 0.1121
# Epoch 70/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0945 - val_loss: 0.1023
# Epoch 71/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0959 - val_loss: 0.0916
# Epoch 72/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0870 - val_loss: 0.0993
# Epoch 73/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0962 - val_loss: 0.0993
# Epoch 74/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0971 - val_loss: 0.0911
# Epoch 75/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0859 - val_loss: 0.0883
# Epoch 76/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0796 - val_loss: 0.0864
# Epoch 77/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0941 - val_loss: 0.0872
# Epoch 78/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0773 - val_loss: 0.0888
# Epoch 79/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0848 - val_loss: 0.0842
# Epoch 80/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0870 - val_loss: 0.1001
# Epoch 81/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0881 - val_loss: 0.0954
# Epoch 82/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0707 - val_loss: 0.0710
# Epoch 83/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0634 - val_loss: 0.0831
# Epoch 84/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0773 - val_loss: 0.0928
# Epoch 85/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0727 - val_loss: 0.0952
# Epoch 86/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0716 - val_loss: 0.0701
# Epoch 87/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0672 - val_loss: 0.0790
# Epoch 88/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0681 - val_loss: 0.0682
# Epoch 89/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0671 - val_loss: 0.0719
# Epoch 90/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0614 - val_loss: 0.0633
# Epoch 91/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0740 - val_loss: 0.0648
# Epoch 92/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0566 - val_loss: 0.0686
# Epoch 93/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0605 - val_loss: 0.0715
# Epoch 94/100
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0563 - val_loss: 0.0599
# Epoch 95/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0600 - val_loss: 0.0576
# Epoch 96/100
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0530 - val_loss: 0.0744
# Epoch 97/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0544 - val_loss: 0.0645
# Epoch 98/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0839 - val_loss: 0.0762
# Epoch 99/100
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0772 - val_loss: 0.0945
# Epoch 100/100
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0875 - val_loss: 0.0768

# %% [markdown]
# ## 結果與評估

# %%
# 使用訓練結果 (inference, 推論)：拿先前分割為測試集的資料 test_i 來測試
inference_o = model.predict(test_i)

# %%
# 畫出 test_i 子資料集的推論結果
inf_o_list = inference_o.tolist()
# plt.gca().invert_yaxis()
for i in range (len (inf_o_list)):
  plt.plot (test_i.iloc [i]['x'], test_i.iloc [i]['y'], 'bo' if inf_o_list [i][0] < .4 else 'ro')

# %%
# 比較原來的資料
# plt.gca().invert_yaxis()
for index, row in dots.iterrows():
  plt.plot (row['x'], row['y'], 'bo' if row ['c'] == 0 else 'ro')

# %%
#結果評估
train_result = model.evaluate(train_i,train_o) # 先以 train_i 為輸入用訓練好的 model 做推論，然後和 train_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 train_result
test_result = model.evaluate(test_i,test_o) # 先以 test_i 為輸入用訓練好的 model 做推論，然後和 test_o (期望正確的輸出) 做比較，算出誤差後回傳值設定為 test_result
print("-----------")
print("train loss:", train_result)
print("test loss:", test_result)
# Out:
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0728
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0650
# -----------
# train loss: 0.07284408807754517
# test loss: 0.06501460820436478

# %%
# 訓練過程 (損失) 誤差變化
 
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.ylabel("loss")
plt.title("loss history")
plt.legend(['train_loss', 'validation_loss'], loc = 'upper left')
plt.xlabel("epoch")
 
plt.tight_layout()
plt.show()

# %%
# 計算原來希望訓練後的模型推論成 1 的測資實際推論為甚麼值的平均值
rdi = dots.loc [dots ['c'] == 1]
rdo = model.predict (rdi.drop (['c'], axis = 1))
sum (rdo) / len (rdo)
# Out:
# array([0.8696684], dtype=float32)

# %%
# 計算原來希望訓練後的模型推論成 0 的測資實際推論為甚麼值的平均值
bli = dots.loc [dots ['c'] == 0]
blo = model.predict (bli.drop (['c'], axis = 1))
sum (blo) / len (blo)
# Out:
# array([0.35798508], dtype=float32)
